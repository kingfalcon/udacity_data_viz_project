# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

bb = pd.read_csv(r"C:\Users\lonmatth\Dropbox (Justin.tv)\97. Continued Education\01. Udacity DA Nanodegree\07. Data Visualization\02. Final Project\baseball_data.csv")

# %%
bb.describe()
# Out:
#             height       weight          avg           HR
# count  1157.000000  1157.000000  1157.000000  1157.000000
# mean     72.756266   184.513397     0.186793    45.359551
# std       2.142272    15.445995     0.106175    74.065110
# min      65.000000   140.000000     0.000000     0.000000
# 25%      71.000000   175.000000     0.138000     1.000000
# 50%      73.000000   185.000000     0.238000    15.000000
# 75%      74.000000   195.000000     0.258000    55.000000
# max      80.000000   245.000000     0.328000   563.000000

# %%
bb.head(10)
# Out:
#              name handedness  height  weight    avg   HR
# 0       Tom Brown          R      73     170  0.000    0
# 1  Denny Lemaster          R      73     182  0.130    4
# 2       Joe Nolan          L      71     175  0.263   27
# 3     Denny Doyle          L      69     175  0.250   16
# 4   Jose Cardenal          R      70     150  0.275  138
# 5       Mike Ryan          R      74     205  0.193   28
# 6  Fritz Peterson          B      72     185  0.159    2
# 7    Dick Bertell          R      72     200  0.250   10
# 8      Rod Kanehl          R      73     180  0.241    6
# 9    Ozzie Osborn          R      74     195  0.000    0

# %%
bb.corr()
# Out:
#           height    weight       avg        HR
# height  1.000000  0.681667 -0.373504  0.002068
# weight  0.681667  1.000000 -0.225471  0.103917
# avg    -0.373504 -0.225471  1.000000  0.426187
# HR      0.002068  0.103917  0.426187  1.000000

# %%
sns.pairplot(bb)

# %%
sns.scatterplot(x=bb["weight"],y=bb["HR"],hue=bb["handedness"])

# %%
sns.scatterplot(x=bb["height"],y=bb["HR"],hue=bb["handedness"])

# %%
sns.scatterplot(x=bb["avg"],y=bb["HR"],hue=bb["handedness"])

# %%
s_plot = sns.scatterplot(x=bb["avg"],y=bb["HR"],hue=bb["handedness"])
s_plot.set(xlim=(np.max(bb["avg"]),np.min(bb["avg"])))
# Out:
# [(0.32799999999999996, 0.0)]

# %%
sns.scatterplot(data=bb,x="height",y="weight",hue="handedness")

# %%
sns.scatterplot(data=bb,x="height",y="avg",hue="handedness")

# %%
sns.scatterplot(data=bb,x="weight",y="avg",hue="handedness")

# %%
bb.sort_values(by="HR",ascending=False).head(10)
# Out:
#                   name handedness  height  weight    avg   HR
# 656     Reggie Jackson          L      72     195  0.262  563
# 995       Mike Schmidt          R      74     195  0.267  548
# 972    Willie Stargell          L      74     188  0.282  475
# 422   Carl Yastrzemski          L      71     175  0.285  452
# 45        Dave Kingman          R      78     210  0.236  442
# 16       Darrell Evans          L      74     200  0.248  414
# 295      Graig Nettles          L      72     180  0.248  390
# 761       Johnny Bench          R      73     197  0.267  389
# 1052          Jim Rice          R      74     200  0.298  382
# 203         Tony Perez          R      74     175  0.279  379

# %%
fg = sns.FacetGrid(bb, col="handedness")
fg.map(sns.scatterplot,"avg","HR",ci=None)
plt.show()

# %%
sns.distplot(bb["avg"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
fg = sns.FacetGrid(bb, col="handedness",sharey=True)
fg.map(sns.distplot,"avg",hist=False,kde=True,bins=25)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
fg = sns.FacetGrid(bb, col="handedness",sharey=True)
fg.map(sns.distplot,"avg",hist=True,kde=False,bins=25)
plt.show()

# %%
sns.scatterplot(x="avg",y="HR",hue="handedness",data=bb[bb.HR>10])

# %%
fg = sns.FacetGrid(bb[bb.HR>10], col="handedness")
fg.map(sns.scatterplot,"avg","HR",ci=None)
plt.show()
